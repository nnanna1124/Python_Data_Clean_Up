# %%
import pandas as pd

# %%
df2 = pd.read_csv('assignment.csv')

# %%
df2
# Out:
#      Unnamed: 0 IMBD title ID               Original titlÊ  Release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          Genrë¨ Duration       Country Content Rating  \
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'IMBD title ID', 'Original titlÊ', 'Release year',
#        'Genrë¨', 'Duration', 'Country', 'Content Rating', 'Director',
#        'Unnamed: 8', 'Income', ' Votes ', 'Score'],
#       dtype='object')

# %%
df2.rename(columns = {'Unnamed: 0': 'unnamed', 'IMBD title ID': 'imdb_title_id', 'Original titlÊ':'original_title', 'Release year':'release_year',
       'Genrë¨':'genre', 'Duration':'duration', 'Country':'country', 'Content Rating':'content_rating', 'Director':'director',
       'Unnamed: 8':'unnamed:8', 'Income':'income', ' Votes ':'votes', 'Score':'score'}, inplace = True)

# %%
df2
# Out:
#      unnamed imdb_title_id               original_title  release_year  \
# 0          0     tt0111161     The Shawshank Redemption    1995-02-10
# 1          1     tt0068646                The Godfather    09 21 1972
# 2          2     tt0468569              The Dark Knight   23 -07-2008
# 3          3     tt0071562       The Godfather: Part II    1975-09-25
# 4          4     tt0110912                 Pulp Fiction    1994-10-28
# ..       ...           ...                          ...           ...
# 96        96     tt0070735                    The Sting    1974-03-21
# 97        97     tt0082096                     Das Boot    1982-03-18
# 98        98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99        99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100      100     tt0045152          Singin' in the Rain    1953-02-05
#
#                           genre duration       country content_rating  \
# ...

# %%
del df2['unnamed:8']

# %%
df2['imdb_title_id'] = df2['imdb_title_id'].str.replace('tt', '')

# %%
df2
# Out:
#      unnamed imdb_title_id               original_title  release_year  \
# 0          0       0111161     The Shawshank Redemption    1995-02-10
# 1          1       0068646                The Godfather    09 21 1972
# 2          2       0468569              The Dark Knight   23 -07-2008
# 3          3       0071562       The Godfather: Part II    1975-09-25
# 4          4       0110912                 Pulp Fiction    1994-10-28
# ..       ...           ...                          ...           ...
# 96        96       0070735                    The Sting    1974-03-21
# 97        97       0082096                     Das Boot    1982-03-18
# 98        98       0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99        99       1832382      Jodaeiye Nader az Simin    2011-10-21
# 100      100       0045152          Singin' in the Rain    1953-02-05
#
#                           genre duration       country content_rating  \
# ...

# %%
df2.rename(columns = {'Original_title':'original_title'}, inplace = True)

# %%
date_format = '%y-%m-%d'

# %%
df2['release_year'] = pd.to_datetime(df2['release_year'], errors='coerce')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_18800\2514538662.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df2['release_year'] = pd.to_datetime(df2['release_year'], errors='coerce')

# %%
df2
# Out:
#      unnamed imdb_title_id               original_title release_year  \
# 0          0       0111161     The Shawshank Redemption   1995-02-10
# 1          1       0068646                The Godfather   1972-09-21
# 2          2       0468569              The Dark Knight   2008-07-23
# 3          3       0071562       The Godfather: Part II   1975-09-25
# 4          4       0110912                 Pulp Fiction   1994-10-28
# ..       ...           ...                          ...          ...
# 96        96       0070735                    The Sting   1974-03-21
# 97        97       0082096                     Das Boot   1982-03-18
# 98        98       0059578  Per qualche dollaro in piÃ¹   1965-12-20
# 99        99       1832382      Jodaeiye Nader az Simin   2011-10-21
# 100      100       0045152          Singin' in the Rain   1953-02-05
#
#                           genre duration       country content_rating  \
# ...

# %%
df2.genre
# Out:
# 0                           Drama
# 1                    Crime, Drama
# 2            Action, Crime, Drama
# 3                    Crime, Drama
# 4                    Crime, Drama
#                   ...
# 96           Comedy, Crime, Drama
# 97     Adventure, Drama, Thriller
# 98                        Western
# 99                          Drama
# 100      Comedy, Musical, Romance
# Name: genre, Length: 101, dtype: object

# %%
df2[['genre_new', 'genre1']] = df2.genre.str.split(",", n=1, expand = True)

# %%
df2
# Out:
#      unnamed imdb_title_id               original_title release_year  \
# 0          0       0111161     The Shawshank Redemption   1995-02-10
# 1          1       0068646                The Godfather   1972-09-21
# 2          2       0468569              The Dark Knight   2008-07-23
# 3          3       0071562       The Godfather: Part II   1975-09-25
# 4          4       0110912                 Pulp Fiction   1994-10-28
# ..       ...           ...                          ...          ...
# 96        96       0070735                    The Sting   1974-03-21
# 97        97       0082096                     Das Boot   1982-03-18
# 98        98       0059578  Per qualche dollaro in piÃ¹   1965-12-20
# 99        99       1832382      Jodaeiye Nader az Simin   2011-10-21
# 100      100       0045152          Singin' in the Rain   1953-02-05
#
#                           genre duration       country content_rating  \
# ...

# %%
del df2['genre1']

# %%
del df2['genre']

# %%
df2.rename(columns = {'genre_new': 'genre'})
# Out:
#     imdb_title_id               original_title release_year duration  \
# 0         0111161     The Shawshank Redemption   1995-02-10      142
# 1         0068646                The Godfather   1972-09-21      175
# 2         0468569              The Dark Knight   2008-07-23      152
# 3         0071562       The Godfather: Part II   1975-09-25      220
# 4         0110912                 Pulp Fiction   1994-10-28
# ..            ...                          ...          ...      ...
# 96        0070735                    The Sting   1974-03-21      129
# 97        0082096                     Das Boot   1982-03-18      149
# 98        0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 99        1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 100       0045152          Singin' in the Rain   1953-02-05      103
#
#           country content_rating              director         income  \
# 0             USA              R        Frank Darabont     $ 28815245
# ...

# %%
del df2['unnamed']

# %%
df2
# Out:
#     imdb_title_id               original_title release_year duration  \
# 0         0111161     The Shawshank Redemption   1995-02-10      142
# 1         0068646                The Godfather   1972-09-21      175
# 2         0468569              The Dark Knight   2008-07-23      152
# 3         0071562       The Godfather: Part II   1975-09-25      220
# 4         0110912                 Pulp Fiction   1994-10-28
# ..            ...                          ...          ...      ...
# 96        0070735                    The Sting   1974-03-21      129
# 97        0082096                     Das Boot   1982-03-18      149
# 98        0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 99        1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 100       0045152          Singin' in the Rain   1953-02-05      103
#
#           country content_rating              director         income  \
# 0             USA              R        Frank Darabont     $ 28815245
# ...

# %%
country_mapping = {
    'USA': 'USA',
    'US': 'USA',
    'US.': 'USA'}

# %%
df2['country'] = df2['country'].replace(country_mapping)

# %%
df2
# Out:
#     imdb_title_id               original_title release_year duration  \
# 0         0111161     The Shawshank Redemption   1995-02-10      142
# 1         0068646                The Godfather   1972-09-21      175
# 2         0468569              The Dark Knight   2008-07-23      152
# 3         0071562       The Godfather: Part II   1975-09-25      220
# 4         0110912                 Pulp Fiction   1994-10-28
# ..            ...                          ...          ...      ...
# 96        0070735                    The Sting   1974-03-21      129
# 97        0082096                     Das Boot   1982-03-18      149
# 98        0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 99        1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 100       0045152          Singin' in the Rain   1953-02-05      103
#
#           country content_rating              director         income  \
# 0             USA              R        Frank Darabont     $ 28815245
# ...

# %%
df2.income
# Out:
# 0         $ 28815245
# 1        $ 246120974
# 2       $ 1005455211
# 3      $ 4o8,035,783
# 4        $ 222831817
#            ...
# 96       $ 156000000
# 97        $ 11487676
# 98        $ 15000000
# 99        $ 22926076
# 100        $ 1864182
# Name: income, Length: 101, dtype: object

# %%
 df2['income'] = df2['income'].str.replace('$', '')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_18800\3921463750.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2['income'] = df2['income'].str.replace('$', '')

# %%
df2
# Out:
#     imdb_title_id               original_title release_year duration  \
# 0         0111161     The Shawshank Redemption   1995-02-10      142
# 1         0068646                The Godfather   1972-09-21      175
# 2         0468569              The Dark Knight   2008-07-23      152
# 3         0071562       The Godfather: Part II   1975-09-25      220
# 4         0110912                 Pulp Fiction   1994-10-28
# ..            ...                          ...          ...      ...
# 96        0070735                    The Sting   1974-03-21      129
# 97        0082096                     Das Boot   1982-03-18      149
# 98        0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 99        1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 100       0045152          Singin' in the Rain   1953-02-05      103
#
#           country content_rating              director        income  \
# 0             USA              R        Frank Darabont      28815245
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   imdb_title_id   100 non-null    object
#  1   original_title  100 non-null    object
#  2   release_year    97 non-null     datetime64[ns]
#  3   duration        99 non-null     object
#  4   country         100 non-null    object
#  5   content_rating  77 non-null     object
#  6   director        100 non-null    object
#  7   income          100 non-null    object
#  8   votes           100 non-null    object
#  9   score           100 non-null    object
#  10  genre_new       100 non-null    object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 8.8+ KB

# %%
df2['income'].describe()
# Out:
# count           100
# unique          100
# top        28815245
# freq              1
# Name: income, dtype: object

# %%
null_counts = df2.isnull().sum(axis=1)

# %%
row_index_with_most_nulls = null_counts.idxmax()

# %%
row_with_most_nulls = df2.loc[row_index_with_most_nulls]

# %%
row_with_most_nulls
# Out:
# imdb_title_id     NaN
# original_title    NaN
# release_year      NaT
# duration          NaN
# country           NaN
# content_rating    NaN
# director          NaN
# income            NaN
# votes             NaN
# score             NaN
# genre_new         NaN
# Name: 13, dtype: object

# %%
df2.drop(index=row_index_with_most_nulls, inplace=True)

# %%
df2
# Out:
#     imdb_title_id               original_title release_year duration  \
# 0         0111161     The Shawshank Redemption   1995-02-10      142
# 1         0068646                The Godfather   1972-09-21      175
# 2         0468569              The Dark Knight   2008-07-23      152
# 3         0071562       The Godfather: Part II   1975-09-25      220
# 4         0110912                 Pulp Fiction   1994-10-28
# ..            ...                          ...          ...      ...
# 96        0070735                    The Sting   1974-03-21      129
# 97        0082096                     Das Boot   1982-03-18      149
# 98        0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 99        1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 100       0045152          Singin' in the Rain   1953-02-05      103
#
#           country content_rating              director        income  \
# 0             USA              R        Frank Darabont      28815245
# ...

# %%
df2['votes'].describe()
# Out:
# count           100
# unique          100
# top       2.278.845
# freq              1
# Name: votes, dtype: object

# %%
df2['votes'] = df2['votes'].apply(lambda x: x.replace('.', '', 1) if isinstance(x, str) and x.count('.') == 2 else x)

# %%
df2
# Out:
#     imdb_title_id               original_title release_year duration  \
# 0         0111161     The Shawshank Redemption   1995-02-10      142
# 1         0068646                The Godfather   1972-09-21      175
# 2         0468569              The Dark Knight   2008-07-23      152
# 3         0071562       The Godfather: Part II   1975-09-25      220
# 4         0110912                 Pulp Fiction   1994-10-28
# ..            ...                          ...          ...      ...
# 96        0070735                    The Sting   1974-03-21      129
# 97        0082096                     Das Boot   1982-03-18      149
# 98        0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 99        1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 100       0045152          Singin' in the Rain   1953-02-05      103
#
#           country content_rating              director        income  \
# 0             USA              R        Frank Darabont      28815245
# ...

# %%
df2['votes'] = df2['votes'].apply(lambda x: str(eval('round(' + x + ')')) if pd.notnull(x) else x)

# %%
df2
# Out:
#     imdb_title_id               original_title release_year duration  \
# 0         0111161     The Shawshank Redemption   1995-02-10      142
# 1         0068646                The Godfather   1972-09-21      175
# 2         0468569              The Dark Knight   2008-07-23      152
# 3         0071562       The Godfather: Part II   1975-09-25      220
# 4         0110912                 Pulp Fiction   1994-10-28
# ..            ...                          ...          ...      ...
# 96        0070735                    The Sting   1974-03-21      129
# 97        0082096                     Das Boot   1982-03-18      149
# 98        0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 99        1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 100       0045152          Singin' in the Rain   1953-02-05      103
#
#           country content_rating              director        income votes  \
# ...

# %%
df2['score'] = df2['score'].str.extract(r'(\d+)')

# %%
df2
# Out:
#     imdb_title_id               original_title release_year duration  \
# 0         0111161     The Shawshank Redemption   1995-02-10      142
# 1         0068646                The Godfather   1972-09-21      175
# 2         0468569              The Dark Knight   2008-07-23      152
# 3         0071562       The Godfather: Part II   1975-09-25      220
# 4         0110912                 Pulp Fiction   1994-10-28
# ..            ...                          ...          ...      ...
# 96        0070735                    The Sting   1974-03-21      129
# 97        0082096                     Das Boot   1982-03-18      149
# 98        0059578  Per qualche dollaro in piÃ¹   1965-12-20      132
# 99        1832382      Jodaeiye Nader az Simin   2011-10-21      123
# 100       0045152          Singin' in the Rain   1953-02-05      103
#
#           country content_rating              director        income votes  \
# ...

# %%
df2['duration'].describe()
# Out:
# count      99
# unique     71
# top       130
# freq        3
# Name: duration, dtype: object

# %%
df2['duration'] = pd.to_numeric(df2['duration'], errors='coerce')

# %%
df2['duration'] = df2['duration'] / 60

# %%
df2
# Out:
#     imdb_title_id               original_title release_year  duration  \
# 0         0111161     The Shawshank Redemption   1995-02-10     142.0
# 1         0068646                The Godfather   1972-09-21     175.0
# 2         0468569              The Dark Knight   2008-07-23     152.0
# 3         0071562       The Godfather: Part II   1975-09-25     220.0
# 4         0110912                 Pulp Fiction   1994-10-28       NaN
# ..            ...                          ...          ...       ...
# 96        0070735                    The Sting   1974-03-21     129.0
# 97        0082096                     Das Boot   1982-03-18     149.0
# 98        0059578  Per qualche dollaro in piÃ¹   1965-12-20     132.0
# 99        1832382      Jodaeiye Nader az Simin   2011-10-21     123.0
# 100       0045152          Singin' in the Rain   1953-02-05     103.0
#
#           country content_rating              director        income votes  \
# ...

# %%
df2['income'] = df2['income'].str.replace('4o8,035,783', '408,035,783')

# %%
df2
# Out:
#     imdb_title_id               original_title release_year  duration  \
# 0         0111161     The Shawshank Redemption   1995-02-10     142.0
# 1         0068646                The Godfather   1972-09-21     175.0
# 2         0468569              The Dark Knight   2008-07-23     152.0
# 3         0071562       The Godfather: Part II   1975-09-25     220.0
# 4         0110912                 Pulp Fiction   1994-10-28       NaN
# ..            ...                          ...          ...       ...
# 96        0070735                    The Sting   1974-03-21     129.0
# 97        0082096                     Das Boot   1982-03-18     149.0
# 98        0059578  Per qualche dollaro in piÃ¹   1965-12-20     132.0
# 99        1832382      Jodaeiye Nader az Simin   2011-10-21     123.0
# 100       0045152          Singin' in the Rain   1953-02-05     103.0
#
#           country content_rating              director        income votes  \
# ...

# %%
df2['income'] = pd.to_numeric(df2['income'], errors='coerce')

# %%
df2['income'].describe()
# Out:
# count    9.900000e+01
# mean     2.980254e+08
# std      4.381130e+08
# min      5.760000e+02
# 25%      2.360835e+07
# 50%      1.089976e+08
# 75%      3.971993e+08
# max      2.797801e+09
# Name: income, dtype: float64

# %%
df2.duration.value_counts()
# Out:
# 122.0    3
# 130.0    3
# 119.0    3
# 149.0    3
# 137.0    3
#         ..
# 98.0     1
# inf      1
# 148.0    1
# 96.0     1
# 123.0    1
# Name: duration, Length: 66, dtype: int64

# %%
df2.country.value_counts()
# Out:
# USA             64
# UK              12
# Italy            4
# Japan            4
# New Zealand      3
# France           3
# South Korea      2
# Germany          2
# Brazil           1
# Italy1           1
# India            1
# Denmark          1
# West Germany     1
# Iran             1
# Name: country, dtype: int64

# %%
df2[df2.country == 'New Zeland']
# Out:
#    imdb_title_id                         original_title release_year  \
# 15       0167261  The Lord of the Rings: The Two Towers   2003-01-16
#
#     duration     country content_rating       director      income votes  \
# 15     179.0  New Zeland          PG-13  Peter Jackson   951227416  1450
#
#    score genre_new
# 15     8    Action

# %%
df2.loc[15, 'country'] = 'New Zealand'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df2
#
# NameError: name 'df2' is not defined
